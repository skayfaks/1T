# %% [markdown]
# `Задание`
# `Основные цели этого задания:`
#
# - Попрактиковаться в борьбе с дисбалансом классов
#
# - Научиться заполнять пропуски в данных
#
# - Научиться использовать категориальные признаки.
#
# `Задача: по различным признакам, связанным с заявкой на грант, предсказать, будет ли заявка принята.`
# `План решения:`
#
# - Загрузите данные из csv файла. Ознакомьтесь с ними, проверьте наличие пропусков, узнайте типы признаков.
#
# `1. Подготовьте данные к обучению моделей:`
#
# - Отделите целевую переменную Grant.Status и выясните, сбалансированы ли классы. Если классы не сбалансированы, используйте в работе хотя бы один из изученных методов борьбы с дисбалансом классов;
#
# `Заполните пропуски`
#
# - в количественных признаках заполните пропуски средними значениями и нулями (у каждой фичи будет по два варианта),
#
# - в категориальных признаках выведите значения, которые они принимают, и найдите признак, где пропуски можно заполнить осмысленным значением. В остальных признаках заполните пропуски значением по умолчанию;
#
# - Преобразуйте категориальные признаки в количественные с помощью прямого кодирования;
#
# - Разделите данные на обучающую и тестовую части;
#
# - Используйте масштабирование для получения признаков одинакового масштаба.
#
# `2. Обучите модели и выберите лучшую:`
#
# - Обучите модель `логистической` `регрессии`, `используя кросс-валидацию`. `Оцените` ее качество с помощью метрики `rocauc`. `Выведите` `топ-10 признаков` по важности, согласно обученной модели;
#
# - Обучите модель `случайного леса`
#
# `Для подбора `гиперпараметров и кросс-валидации используйте `структуру GridSearchCV`,
#
# - Выберите наилучший вариант случайного леса и выведите его параметры,
#
# - Оцените качество выбранной модели с помощью метрики rocauc,
#
# - Выведите топ-10 признаков по важности. Используйте `атрибут` `feature_importances_`, чтобы узнать важность признаков в деревянных моделях.
#
# Напишите вывод, в котором будет содержаться информация о том, какие признаки важны согласно обеим моделям, и какая модель оказалась наилучшей для решения поставленной задачи.

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('grant_data_imb.csv')
df.shape
# Out:
# (4113, 39)

# %% [markdown]
# `1. Подготовьте данные к обучению моделей:`
#
# - Отделите целевую переменную Grant.Status и выясните, сбалансированы ли классы. Если классы не сбалансированы, используйте в работе хотя бы один из изученных методов борьбы с дисбалансом классов;
#
# `Заполните пропуски`
#
# - в количественных признаках заполните пропуски средними значениями и нулями (у каждой фичи будет по два варианта),
#
# - в категориальных признаках выведите значения, которые они принимают, и найдите признак, где пропуски можно заполнить осмысленным значением. В остальных признаках заполните пропуски значением по умолчанию;
#
# - Преобразуйте категориальные признаки в количественные с помощью прямого кодирования;
#
# - Разделите данные на обучающую и тестовую части;
#
# - Используйте масштабирование для получения признаков одинакового масштаба.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4113 entries, 0 to 4112
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Grant.Status                            4113 non-null   int64
#  1   Sponsor.Code                            3856 non-null   object
#  2   Grant.Category.Code                     3856 non-null   object
#  3   Contract.Value.Band...see.note.A        1953 non-null   object
#  4   RFCD.Code.1                             3853 non-null   float64
#  5   RFCD.Percentage.1                       3853 non-null   float64
#  6   RFCD.Code.2                             3853 non-null   float64
#  7   RFCD.Percentage.2                       3853 non-null   float64
#  8   RFCD.Code.3                             3853 non-null   float64
#  9   RFCD.Percentage.3                       3853 non-null   float64
#  10  RFCD.Code.4                             3853 non-null   float64
#  11  RFCD.Percentage.4                       3853 non-null   float64
#  12  RFCD.Code.5                             3853 non-null   float64
#  13  RFCD.Percentage.5                       3853 non-null   float64
#  14  SEO.Code.1                              3837 non-null   float64
#  15  SEO.Percentage.1                        3837 non-null   float64
#  16  SEO.Code.2                              3837 non-null   float64
#  17  SEO.Percentage.2                        3837 non-null   float64
#  18  SEO.Code.3                              3837 non-null   float64
#  19  SEO.Percentage.3                        3837 non-null   float64
#  20  SEO.Code.4                              3837 non-null   float64
#  21  SEO.Percentage.4                        3837 non-null   float64
#  22  SEO.Code.5                              3837 non-null   float64
#  23  SEO.Percentage.5                        3837 non-null   float64
#  24  Person.ID.1                             3826 non-null   float64
#  25  Role.1                                  4067 non-null   object
#  26  Year.of.Birth.1                         3825 non-null   float64
#  27  Country.of.Birth.1                      3447 non-null   object
#  28  Home.Language.1                         394 non-null    object
#  29  Dept.No..1                              3665 non-null   float64
#  30  Faculty.No..1                           3664 non-null   float64
#  31  With.PHD.1                              2332 non-null   object
#  32  No..of.Years.in.Uni.at.Time.of.Grant.1  3354 non-null   object
#  33  Number.of.Successful.Grant.1            3826 non-null   float64
#  34  Number.of.Unsuccessful.Grant.1          3826 non-null   float64
#  35  A..1                                    3826 non-null   float64
#  36  A.1                                     3826 non-null   float64
#  37  B.1                                     3826 non-null   float64
#  38  C.1                                     3826 non-null   float64
# dtypes: float64(30), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df.describe(include='all').fillna('-').T
# Out:
#                                          count unique                 top  \
# Grant.Status                            4113.0      -                   -
# Sponsor.Code                              3856    226                  4D
# Grant.Category.Code                       3856     13                 10A
# Contract.Value.Band...see.note.A          1953     16                  A
# RFCD.Code.1                             3853.0      -                   -
# RFCD.Percentage.1                       3853.0      -                   -
# RFCD.Code.2                             3853.0      -                   -
# RFCD.Percentage.2                       3853.0      -                   -
# RFCD.Code.3                             3853.0      -                   -
# RFCD.Percentage.3                       3853.0      -                   -
# RFCD.Code.4                             3853.0      -                   -
# RFCD.Percentage.4                       3853.0      -                   -
# RFCD.Code.5                             3853.0      -                   -
# RFCD.Percentage.5                       3853.0      -                   -
# SEO.Code.1                              3837.0      -                   -
# SEO.Percentage.1                        3837.0      -                   -
# SEO.Code.2                              3837.0      -                   -
# SEO.Percentage.2                        3837.0      -                   -
# SEO.Code.3                              3837.0      -                   -
# SEO.Percentage.3                        3837.0      -                   -
# SEO.Code.4                              3837.0      -                   -
# SEO.Percentage.4                        3837.0      -                   -
# SEO.Code.5                              3837.0      -                   -
# SEO.Percentage.5                        3837.0      -                   -
# Person.ID.1                             3826.0      -                   -
# Role.1                                    4067      7  CHIEF_INVESTIGATOR
# Year.of.Birth.1                         3825.0      -                   -
# Country.of.Birth.1                        3447     10           Australia
# Home.Language.1                            394      2             English
# Dept.No..1                              3665.0      -                   -
# Faculty.No..1                           3664.0      -                   -
# With.PHD.1                                2332      1                Yes
# No..of.Years.in.Uni.at.Time.of.Grant.1    3354      5            >=0 to 5
# Number.of.Successful.Grant.1            3826.0      -                   -
# Number.of.Unsuccessful.Grant.1          3826.0      -                   -
# A..1                                    3826.0      -                   -
# A.1                                     3826.0      -                   -
# B.1                                     3826.0      -                   -
# C.1                                     3826.0      -                   -
#
#                                         freq           mean            std  \
# Grant.Status                               -       0.207634       0.405663
# Sponsor.Code                            1006              -              -
# Grant.Category.Code                     2050              -              -
# Contract.Value.Band...see.note.A         961              -              -
# RFCD.Code.1                                -  314904.682845   47163.318702
# RFCD.Percentage.1                          -       74.69686      26.875419
# RFCD.Code.2                                -  161386.717104  161577.090361
# RFCD.Percentage.2                          -      17.642616      19.259007
# RFCD.Code.3                                -   96437.197508  148599.260202
# RFCD.Percentage.3                          -       7.089541      11.937533
# RFCD.Code.4                                -    6835.177005   45889.060627
# RFCD.Percentage.4                          -       0.442512       3.228834
# RFCD.Code.5                                -    1767.989878   23598.311088
# RFCD.Percentage.5                          -       0.128471       1.837888
# SEO.Code.1                                 -   729027.71436   34662.088163
# SEO.Percentage.1                           -      70.557024      26.868701
# SEO.Code.2                                 -   443260.50847  356778.379675
# SEO.Percentage.2                           -      21.209617       20.06294
# SEO.Code.3                                 -  233810.547824  340800.380818
# SEO.Percentage.3                           -       7.294866      12.037658
# SEO.Code.4                                 -   32557.909044  149974.448555
# SEO.Percentage.4                           -       0.719312       3.715814
# SEO.Code.5                                 -    9602.635132   82817.740308
# SEO.Percentage.5                           -       0.218921       2.217695
# Person.ID.1                                -   171788.39702  254226.392537
# Role.1                                  3640              -              -
# Year.of.Birth.1                            -    1962.684967       9.421352
# Country.of.Birth.1                      2530              -              -
# Home.Language.1                          316              -              -
# Dept.No..1                                 -    2440.684857     740.105499
# Faculty.No..1                              -      23.830786      11.346395
# With.PHD.1                              2332              -              -
# No..of.Years.in.Uni.at.Time.of.Grant.1  1337              -              -
# Number.of.Successful.Grant.1               -       1.050183       1.482831
# Number.of.Unsuccessful.Grant.1             -       2.427339       2.976874
# A..1                                       -       3.594877        7.15509
# A.1                                        -       5.230528       7.758928
# B.1                                        -         4.1184       5.385708
# C.1                                        -       2.232619       4.349171
#
#                                              min       25%       50%  \
# Grant.Status                                 0.0       0.0       0.0
# Sponsor.Code                                   -         -         -
# Grant.Category.Code                            -         -         -
# Contract.Value.Band...see.note.A               -         -         -
# RFCD.Code.1                             210000.0  280401.0  320801.0
# RFCD.Percentage.1                            5.0      50.0      80.0
# RFCD.Code.2                                  0.0       0.0  240202.0
# RFCD.Percentage.2                            0.0       0.0      10.0
# RFCD.Code.3                                  0.0       0.0       0.0
# RFCD.Percentage.3                            0.0       0.0       0.0
# RFCD.Code.4                                  0.0       0.0       0.0
# RFCD.Percentage.4                            0.0       0.0       0.0
# RFCD.Code.5                                  0.0       0.0       0.0
# RFCD.Percentage.5                            0.0       0.0       0.0
# SEO.Code.1                              610102.0  730104.0  730110.0
# SEO.Percentage.1                             5.0      50.0      70.0
# SEO.Code.2                                   0.0       0.0  730101.0
# SEO.Percentage.2                             0.0       0.0      20.0
# SEO.Code.3                                   0.0       0.0       0.0
# SEO.Percentage.3                             0.0       0.0       0.0
# SEO.Code.4                                   0.0       0.0       0.0
# SEO.Percentage.4                             0.0       0.0       0.0
# SEO.Code.5                                   0.0       0.0       0.0
# SEO.Percentage.5                             0.0       0.0       0.0
# Person.ID.1                                362.0  27730.75   71234.5
# Role.1                                         -         -         -
# Year.of.Birth.1                           1930.0    1955.0    1965.0
# Country.of.Birth.1                             -         -         -
# Home.Language.1                                -         -         -
# Dept.No..1                                  28.0    2298.0    2653.0
# Faculty.No..1                                1.0      25.0      25.0
# With.PHD.1                                     -         -         -
# No..of.Years.in.Uni.at.Time.of.Grant.1         -         -         -
# Number.of.Successful.Grant.1                 0.0       0.0       1.0
# Number.of.Unsuccessful.Grant.1               0.0       1.0       1.0
# A..1                                         0.0       0.0       1.0
# A.1                                          0.0       0.0       3.0
# B.1                                          0.0       0.0       2.0
# C.1                                          0.0       0.0       1.0
#
#                                               75%        max
# Grant.Status                                  0.0        1.0
# Sponsor.Code                                    -          -
# Grant.Category.Code                             -          -
# Contract.Value.Band...see.note.A                -          -
# RFCD.Code.1                              321202.0   999999.0
# RFCD.Percentage.1                           100.0      100.0
# RFCD.Code.2                              320702.0   440207.0
# RFCD.Percentage.2                            30.0       90.0
# RFCD.Code.3                              270208.0   440207.0
# RFCD.Percentage.3                            15.0       70.0
# RFCD.Code.4                                   0.0   440105.0
# RFCD.Percentage.4                             0.0       70.0
# RFCD.Code.5                                   0.0   419999.0
# RFCD.Percentage.5                             0.0       40.0
# SEO.Code.1                               740301.0   999999.0
# SEO.Percentage.1                            100.0      100.0
# SEO.Code.2                               730211.0   780199.0
# SEO.Percentage.2                             40.0       90.0
# SEO.Code.3                               730102.0   780199.0
# SEO.Percentage.3                             15.0       80.0
# SEO.Code.4                                    0.0   780108.0
# SEO.Percentage.4                              0.0       40.0
# SEO.Code.5                                    0.0   780105.0
# SEO.Percentage.5                              0.0       50.0
# Person.ID.1                             120868.25  1145967.0
# Role.1                                          -          -
# Year.of.Birth.1                            1970.0     1985.0
# Country.of.Birth.1                              -          -
# Home.Language.1                                 -          -
# Dept.No..1                                 2813.0     4418.0
# Faculty.No..1                                25.0      187.0
# With.PHD.1                                      -          -
# No..of.Years.in.Uni.at.Time.of.Grant.1          -          -
# Number.of.Successful.Grant.1                  2.0       13.0
# Number.of.Unsuccessful.Grant.1                3.0       24.0
# A..1                                          4.0      123.0
# A.1                                           7.0       87.0
# B.1                                           6.0       59.0
# C.1                                           3.0       61.0

# %%
# выводим количество уникальных значений в категориальных столбцах
categorical_columns = df.select_dtypes(include=['object']).columns 

for category in categorical_columns:            
    print("Статистика для столбца -", category)
    print(df[category].value_counts())          
    print(df[category].describe())              
    print(f'{"-"*75}')
# Out:
# Статистика для столбца - Sponsor.Code
# Sponsor.Code
# 4D      1006
# 2B       915
# 21A      375
# 24D      114
# 40D       91
#         ...
# 242B       1
# 308D       1
# 284D       1
# 259C       1
# 225A       1
# Name: count, Length: 226, dtype: int64
# count     3856
# unique     226
# top         4D
# freq      1006
# Name: Sponsor.Code, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - Grant.Category.Code
# Grant.Category.Code
# 10A    2050
# 30B     707
# 50A     375
# 10B     211
# 20C     180
# 30C     147
# 30D      93
# 20A      49
# 30G      35
# 30E       5
# 30A       2
# 40C       1
# 30F       1
# Name: count, dtype: int64
# count     3856
# unique      13
# top        10A
# freq      2050
# Name: Grant.Category.Code, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - Contract.Value.Band...see.note.A
# Contract.Value.Band...see.note.A
# A     961
# B     305
# C     159
# D     151
# G     135
# E      98
# F      75
# H      33
# J      18
# I      11
# P       2
# K       1
# M       1
# O       1
# Q       1
# L       1
# Name: count, dtype: int64
# count     1953
# unique      16
# top         A
# freq       961
# Name: Contract.Value.Band...see.note.A, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - Role.1
# Role.1
# CHIEF_INVESTIGATOR         3640
# EXT_CHIEF_INVESTIGATOR      230
# PRINCIPAL_SUPERVISOR        144
# DELEGATED_RESEARCHER         36
# STUD_CHIEF_INVESTIGATOR      10
# HONVISIT                      6
# EXTERNAL_ADVISOR              1
# Name: count, dtype: int64
# count                   4067
# unique                     7
# top       CHIEF_INVESTIGATOR
# freq                    3640
# Name: Role.1, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - Country.of.Birth.1
# Country.of.Birth.1
# Australia                 2530
# Great Britain              304
# Western Europe             158
# Asia Pacific               149
# North America              121
# Eastern Europe              60
# Middle East and Africa      40
# The Americas                32
# New Zealand                 31
# South Africa                22
# Name: count, dtype: int64
# count          3447
# unique           10
# top       Australia
# freq           2530
# Name: Country.of.Birth.1, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - Home.Language.1
# Home.Language.1
# English    316
# Other       78
# Name: count, dtype: int64
# count         394
# unique          2
# top       English
# freq          316
# Name: Home.Language.1, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - With.PHD.1
# With.PHD.1
# Yes     2332
# Name: count, dtype: int64
# count     2332
# unique       1
# top       Yes
# freq      2332
# Name: With.PHD.1, dtype: object
# ---------------------------------------------------------------------------
# Статистика для столбца - No..of.Years.in.Uni.at.Time.of.Grant.1
# No..of.Years.in.Uni.at.Time.of.Grant.1
# >=0 to 5        1337
# >5 to 10         739
# Less than 0      496
# >10 to 15        418
# more than 15     364
# Name: count, dtype: int64
# count         3354
# unique           5
# top       >=0 to 5
# freq          1337
# Name: No..of.Years.in.Uni.at.Time.of.Grant.1, dtype: object
# ---------------------------------------------------------------------------

# %%
print(f'Количество дубликатов в DataFrame = {df.duplicated().sum()}')
# Out:
# Количество дубликатов в DataFrame = 65

# %%
df.drop_duplicates(inplace=True)

# %%
print(f'    Количество NaN в DataFrame \n{"-"*50}\n{df.isna().sum()}')
# Out:
#     Количество NaN в DataFrame
# --------------------------------------------------
# Grant.Status                                 0
# Sponsor.Code                               245
# Grant.Category.Code                        245
# Contract.Value.Band...see.note.A          2117
# RFCD.Code.1                                249
# RFCD.Percentage.1                          249
# RFCD.Code.2                                249
# RFCD.Percentage.2                          249
# RFCD.Code.3                                249
# RFCD.Percentage.3                          249
# RFCD.Code.4                                249
# RFCD.Percentage.4                          249
# RFCD.Code.5                                249
# RFCD.Percentage.5                          249
# SEO.Code.1                                 264
# SEO.Percentage.1                           264
# SEO.Code.2                                 264
# SEO.Percentage.2                           264
# SEO.Code.3                                 264
# SEO.Percentage.3                           264
# SEO.Code.4                                 264
# SEO.Percentage.4                           264
# SEO.Code.5                                 264
# SEO.Percentage.5                           264
# Person.ID.1                                264
# Role.1                                      41
# Year.of.Birth.1                            265
# Country.of.Birth.1                         639
# Home.Language.1                           3659
# Dept.No..1                                 424
# Faculty.No..1                              425
# With.PHD.1                                1744
# No..of.Years.in.Uni.at.Time.of.Grant.1     735
# Number.of.Successful.Grant.1               264
# Number.of.Unsuccessful.Grant.1             264
# A..1                                       264
# A.1                                        264
# B.1                                        264
# C.1                                        264
# dtype: int64

# %% [markdown]
# Разделим данные на фичи и целевой признак

# %%
target = df['Grant.Status']
features = df.drop(['Grant.Status'], axis = 1)
target.value_counts()
# Out:
# Grant.Status
# 0    3209
# 1     839
# Name: count, dtype: int64

# %% [markdown]
# - `Данные в датасете представлены разрозненно. Имеются пропуски, несколько категориальных столбцов. наблюдается сильный дисбаланс классов.`

# %%
def upsample(features, target, repeat=10): # repeat - отвечает за то во сколько раз необходимо увеличить объекты более редкого класса 
    # разделяем объекты разных классов и информацию о них по разным переменным
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    # дублируем записи объектов более редкого класса
    if len(target_ones) > len(target_zeros):
        repeat = round(len(target_ones) / len(target_zeros))
        features_upsampled = pd.concat([features_ones] + [features_zeros] * repeat)
        target_upsampled = pd.concat([target_ones] + [target_zeros] * repeat)
    else:
        repeat = round(len(target_zeros) / len(target_ones))
        features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
        target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    # перемешиваем объекты
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=23) # перемешиваем 
    
    return features_upsampled, target_upsampled

# %%
features_train_upsampled, target_train_upsampled = upsample(features, target)
target_train_upsampled.value_counts()
# Out:
# Grant.Status
# 1    3356
# 0    3209
# Name: count, dtype: int64

# %% [markdown]
# - Классы сбалансированны

# %% [markdown]
# заполняем пропуски средними значениями и нулями (у каждой фичи будет по два варианта)

# %%
for column in features.columns:
    if np.issubdtype(features[column].dtype, np.float64): # является ли тип данных столбца float64
        new_column = f'{column}_0'
        features[new_column] = features[column].fillna(0) # создадим столбец new_column с заменой отсутствующих значений на 0
        features[column].fillna(features[column].mean(), inplace=True) # исходном столбце  `column` отсутствующие значения заменяются на среднее

# %% [markdown]
# - проанализируем категориальные признаки

# %%
for col in features.columns:
    if features[col].dtype == 'object':
        print(col)
        print(features[col].value_counts())
        print("-"*50)
# Out:
# Sponsor.Code
# Sponsor.Code
# 4D      979
# 2B      913
# 21A     374
# 24D     114
# 40D      89
#        ...
# 308D      1
# 284D      1
# 259C      1
# 331C      1
# 225A      1
# Name: count, Length: 226, dtype: int64
# --------------------------------------------------
# Grant.Category.Code
# Grant.Category.Code
# 10A    2020
# 30B     699
# 50A     374
# 10B     207
# 20C     177
# 30C     145
# 30D      91
# 20A      48
# 30G      34
# 30E       5
# 30A       1
# 40C       1
# 30F       1
# Name: count, dtype: int64
# --------------------------------------------------
# Contract.Value.Band...see.note.A
# Contract.Value.Band...see.note.A
# A     951
# B     302
# C     156
# D     147
# G     135
# E      97
# F      75
# H      32
# J      18
# I      11
# P       2
# K       1
# M       1
# O       1
# Q       1
# L       1
# Name: count, dtype: int64
# --------------------------------------------------
# Role.1
# Role.1
# CHIEF_INVESTIGATOR         3601
# EXT_CHIEF_INVESTIGATOR      212
# PRINCIPAL_SUPERVISOR        141
# DELEGATED_RESEARCHER         36
# STUD_CHIEF_INVESTIGATOR      10
# HONVISIT                      6
# EXTERNAL_ADVISOR              1
# Name: count, dtype: int64
# --------------------------------------------------
# Country.of.Birth.1
# Country.of.Birth.1
# Australia                 2501
# Great Britain              298
# Western Europe             155
# Asia Pacific               149
# North America              121
# Eastern Europe              60
# Middle East and Africa      40
# The Americas                32
# New Zealand                 31
# South Africa                22
# Name: count, dtype: int64
# --------------------------------------------------
# Home.Language.1
# Home.Language.1
# English    312
# Other       77
# Name: count, dtype: int64
# --------------------------------------------------
# With.PHD.1
# With.PHD.1
# Yes     2304
# Name: count, dtype: int64
# --------------------------------------------------
# No..of.Years.in.Uni.at.Time.of.Grant.1
# No..of.Years.in.Uni.at.Time.of.Grant.1
# >=0 to 5        1321
# >5 to 10         728
# Less than 0      492
# >10 to 15        413
# more than 15     359
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# - заполним пропуски в категориальных столбцах. Принято решение заполнить строкой `no_information`

# %%
features['With.PHD.1'].fillna('NO', inplace=True)

for col in features.columns:
    if features[col].dtype == 'object':
        features[col].fillna('no_information', inplace=True)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4048 entries, 0 to 4112
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Sponsor.Code                            4048 non-null   object
#  1   Grant.Category.Code                     4048 non-null   object
#  2   Contract.Value.Band...see.note.A        4048 non-null   object
#  3   RFCD.Code.1                             4048 non-null   float64
#  4   RFCD.Percentage.1                       4048 non-null   float64
#  5   RFCD.Code.2                             4048 non-null   float64
#  6   RFCD.Percentage.2                       4048 non-null   float64
#  7   RFCD.Code.3                             4048 non-null   float64
#  8   RFCD.Percentage.3                       4048 non-null   float64
#  9   RFCD.Code.4                             4048 non-null   float64
#  10  RFCD.Percentage.4                       4048 non-null   float64
#  11  RFCD.Code.5                             4048 non-null   float64
#  12  RFCD.Percentage.5                       4048 non-null   float64
#  13  SEO.Code.1                              4048 non-null   float64
#  14  SEO.Percentage.1                        4048 non-null   float64
#  15  SEO.Code.2                              4048 non-null   float64
#  16  SEO.Percentage.2                        4048 non-null   float64
#  17  SEO.Code.3                              4048 non-null   float64
#  18  SEO.Percentage.3                        4048 non-null   float64
#  19  SEO.Code.4                              4048 non-null   float64
#  20  SEO.Percentage.4                        4048 non-null   float64
#  21  SEO.Code.5                              4048 non-null   float64
#  22  SEO.Percentage.5                        4048 non-null   float64
#  23  Person.ID.1                             4048 non-null   float64
#  24  Role.1                                  4048 non-null   object
#  25  Year.of.Birth.1                         4048 non-null   float64
#  26  Country.of.Birth.1                      4048 non-null   object
#  27  Home.Language.1                         4048 non-null   object
#  28  Dept.No..1                              4048 non-null   float64
#  29  Faculty.No..1                           4048 non-null   float64
#  30  With.PHD.1                              4048 non-null   object
#  31  No..of.Years.in.Uni.at.Time.of.Grant.1  4048 non-null   object
#  32  Number.of.Successful.Grant.1            4048 non-null   float64
#  33  Number.of.Unsuccessful.Grant.1          4048 non-null   float64
#  34  A..1                                    4048 non-null   float64
#  35  A.1                                     4048 non-null   float64
#  36  B.1                                     4048 non-null   float64
#  37  C.1                                     4048 non-null   float64
#  38  RFCD.Code.1_0                           4048 non-null   float64
#  39  RFCD.Percentage.1_0                     4048 non-null   float64
#  40  RFCD.Code.2_0                           4048 non-null   float64
#  41  RFCD.Percentage.2_0                     4048 non-null   float64
#  42  RFCD.Code.3_0                           4048 non-null   float64
#  43  RFCD.Percentage.3_0                     4048 non-null   float64
#  44  RFCD.Code.4_0                           4048 non-null   float64
#  45  RFCD.Percentage.4_0                     4048 non-null   float64
#  46  RFCD.Code.5_0                           4048 non-null   float64
#  47  RFCD.Percentage.5_0                     4048 non-null   float64
#  48  SEO.Code.1_0                            4048 non-null   float64
#  49  SEO.Percentage.1_0                      4048 non-null   float64
#  50  SEO.Code.2_0                            4048 non-null   float64
#  51  SEO.Percentage.2_0                      4048 non-null   float64
#  52  SEO.Code.3_0                            4048 non-null   float64
#  53  SEO.Percentage.3_0                      4048 non-null   float64
#  54  SEO.Code.4_0                            4048 non-null   float64
#  55  SEO.Percentage.4_0                      4048 non-null   float64
#  56  SEO.Code.5_0                            4048 non-null   float64
#  57  SEO.Percentage.5_0                      4048 non-null   float64
#  58  Person.ID.1_0                           4048 non-null   float64
#  59  Year.of.Birth.1_0                       4048 non-null   float64
#  60  Dept.No..1_0                            4048 non-null   float64
#  61  Faculty.No..1_0                         4048 non-null   float64
#  62  Number.of.Successful.Grant.1_0          4048 non-null   float64
#  63  Number.of.Unsuccessful.Grant.1_0        4048 non-null   float64
#  64  A..1_0                                  4048 non-null   float64
#  65  A.1_0                                   4048 non-null   float64
#  66  B.1_0                                   4048 non-null   float64
#  67  C.1_0                                   4048 non-null   float64
# dtypes: float64(60), object(8)
# memory usage: 2.1+ MB

# %% [markdown]
# - преобразовываем категориальные переменные с помощью One-Hot Encoding (одномерного кодирования) функция `get_dummies()\
# Эта функция создает новые столбцы для каждого уникального значения категориальной переменной и устанавливает значение 1 в соответствующем столбце, если значение присутствует, и 0, если значение отсутствует.

# %%
features_ohe = pd.get_dummies(features, drop_first=True) # выкидываем один из сгенерированных столбцов
features_ohe.sample()
# Out:
#       RFCD.Code.1  RFCD.Percentage.1  RFCD.Code.2  RFCD.Percentage.2  \
# 2964     320702.0              100.0          0.0                0.0
#
#       RFCD.Code.3  RFCD.Percentage.3  RFCD.Code.4  RFCD.Percentage.4  \
# 2964          0.0                0.0          0.0                0.0
#
#       RFCD.Code.5  RFCD.Percentage.5  ...  Country.of.Birth.1_Western Europe  \
# 2964          0.0                0.0  ...                              False
#
#       Country.of.Birth.1_no_information  Home.Language.1_Other  \
# 2964                              False                  False
#
#       Home.Language.1_no_information  With.PHD.1_Yes   \
# 2964                            True             True
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_>5 to 10  \
# 2964                                            False
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_>=0 to 5  \
# 2964                                            False
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_Less than 0  \
# 2964                                              False
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_more than 15  \
# 2964                                              False
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_no_information
# 2964                                              False
#
# [1 rows x 340 columns]

# %%
features_train, features_valid, target_train, target_valid = train_test_split(features_ohe, target, test_size=0.25, random_state=25)

# %% [markdown]
# - Для обучения нашей линейной модели мы приводим столбцы к одному масштабу в этом нам поможет StandardScaler

# %%
scaler = StandardScaler()

# настраиваем только на обучающей части
scaler.fit(features_train) 

# применяем обученный StandardScaler на обои  части 
features_train_sc = scaler.transform(features_train)
features_valid_sc = scaler.transform(features_valid)

# %%
pd.DataFrame(features_train_sc, columns=features_train.columns).sample()
# Out:
#       RFCD.Code.1  RFCD.Percentage.1  RFCD.Code.2  RFCD.Percentage.2  \
# 2227    -0.760878          -1.345645     0.759318            1.19957
#
#       RFCD.Code.3  RFCD.Percentage.3  RFCD.Code.4  RFCD.Percentage.4  \
# 2227     1.277656           1.139986    -0.152962          -0.145071
#
#       RFCD.Code.5  RFCD.Percentage.5  ...  Country.of.Birth.1_Western Europe  \
# 2227    -0.074909           -0.07024  ...                          -0.195713
#
#       Country.of.Birth.1_no_information  Home.Language.1_Other  \
# 2227                          -0.430667              -0.137084
#
#       Home.Language.1_no_information  With.PHD.1_Yes   \
# 2227                        0.332357         0.864196
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_>5 to 10  \
# 2227                                         2.126029
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_>=0 to 5  \
# 2227                                        -0.705012
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_Less than 0  \
# 2227                                          -0.373684
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_more than 15  \
# 2227                                          -0.314966
#
#       No..of.Years.in.Uni.at.Time.of.Grant.1_no_information
# 2227                                          -0.466178
#
# [1 rows x 340 columns]

# %% [markdown]
# - получаем признаки примерно одного масштаба

# %% [markdown]
# -------------
# `2. Обучите модели и выберите лучшую:`
#
# - Обучите модель `логистической` `регрессии`, `используя кросс-валидацию`. `Оцените` ее качество с помощью метрики `rocauc`. `Выведите` `топ-10 признаков` по важности, согласно обученной модели;
#
# `2.1` Обучите модель `случайного леса`
#
# - `Для подбора `гиперпараметров и кросс-валидации используйте `структуру GridSearchCV`,
#
# - Выберите наилучший вариант случайного леса и выведите его параметры,
#
# - Оцените качество выбранной модели с помощью метрики rocauc,
#
# - Выведите топ-10 признаков по важности. Используйте `атрибут` `feature_importances_`, чтобы узнать важность признаков в деревянных моделях.

# %%
model = LogisticRegressionCV(solver='liblinear', random_state=15, class_weight='balanced', cv=12)
model.fit(features_train_sc,target_train)
roc_auc_score(target_valid,model.predict_proba(features_valid_sc)[:,1])
# Out:
# 0.8543820267710811

# %% [markdown]
# - посмотрим какие Фичи самые важные

# %%
data = pd.DataFrame(zip(list(features_ohe.columns), list(abs(model.coef_[0]))), columns=['features', 'importance'])
sorted_data = data.sort_values(by='importance', ascending=False).head(10)

display(sorted_data)
# Out:
#                                             features  importance
# 53                                   Faculty.No..1_0    1.909341
# 51                                 Year.of.Birth.1_0    1.887674
# 23                                     Faculty.No..1    1.520222
# 314  Contract.Value.Band...see.note.A_no_information    1.455511
# 317                    Role.1_EXT_CHIEF_INVESTIGATOR    1.427784
# 244                                  Sponsor.Code_4D    1.254921
# 52                                      Dept.No..1_0    1.142255
# 262                                  Sponsor.Code_6B    1.127367
# 55                  Number.of.Unsuccessful.Grant.1_0    1.032548
# 199                                  Sponsor.Code_2B    1.029650

# %% [markdown]
# ОБУЧИМ МОДЕЛЬ СЛУЧАЙНОГО ЛЕСА
#
# -- создаем объект классификатора RandomForestClassifier(), задаем набор гиперпараметров
# -  `n_estimators` : количество деревьев в лесу (от 10 до 50 с шагом 10)
# -  `max_depth` : максимальная глубина деревьев (от 1 до 12 с шагом 2)
# -  `min_samples_leaf` : минимальное количество объектов в листе дерева (от 1 до 7)
# -  `min_samples_split` : минимальное количество объектов, необходимое для разделения узла (от 2 до 9)
#
# GridSearchCV (поиск по сетке) выполняет перебор всех возможных комбинаций гиперпараметров, заданных в  `parametrs_RFC` , и оценивает производительность модели с помощью кросс-валидации на 10 фолдах (cv=10).
#
# `features_train_sc`  и  `target_train`  представляют собой тренировочные данные, которые будут использоваться для обучения модели.
#
# После выполнения  `grid.fit()` , можно получить наилучшие значения гиперпараметров с помощью атрибута  `best_params_`  объекта  `grid` . Например,  `grid.best_params_`  вернет словарь с наилучшими значениями гиперпараметров, найденными в результате поиска.

# %%
clf = RandomForestClassifier()
parametrs_RFC = {'n_estimators': range (10,51,10),
                 'max_depth': range (1,13,2),
                 'min_samples_leaf': range (1,8),
                 'min_samples_split': range (2,10)}

grid = GridSearchCV(clf, parametrs_RFC, cv=10)
grid.fit(features_train_sc,target_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': range(10, 51, 10)})

# %% [markdown]
# отобразим подобранные параметры модели

# %%
grid.best_params_
# Out:
# {'max_depth': 11,
#  'min_samples_leaf': 1,
#  'min_samples_split': 6,
#  'n_estimators': 30}

# %% [markdown]
# Обучаем модель `RandomForestClassifier`, задаем гиперпараметры, используя функцию fit(). Затем вычислим значение метрики `roc_auc_score` для `валидационных` данных, используя функцию predict_log_proba() для получения предсказанных `вероятностей` и выбирая второй столбец с помощью [:,1].

# %%
model = RandomForestClassifier(random_state=12, class_weight='balanced', max_depth=11, min_samples_leaf=3, min_samples_split=6, n_estimators=41)
model.fit(features_train_sc,target_train)
roc_auc_score(target_valid, model.predict_log_proba(features_valid_sc)[:,1])
# Out:
# 0.913395743921026

# %% [markdown]
# Отразим Фичи и их значение при обучении модели RandomForestClassifier

# %% [markdown]
# Для этого:
#
# 1. Создам DataFrame. В этом DataFrame каждая строка содержит пару значений: название признака (features_ohe.columns) и его важность (model.feature_importances_).
# 2. Задам названия столбцов DataFrame с помощью параметра  `columns`.
# 3. Отсортирую DataFrame по столбцу 'importance' в порядке убывания с помощью функции `sort_values(by=['importance'],ascending=False)`.
# 4. Из отсортированного DataFrame выбираю первых 15 строк.

# %%
pd.DataFrame(zip(list(features_ohe.columns), model.feature_importances_),
             columns = ['features', 'importance']).sort_values(by=['importance'],ascending=False).head(15)
# Out:
#                                             features  importance
# 314  Contract.Value.Band...see.note.A_no_information    0.173428
# 25                    Number.of.Unsuccessful.Grant.1    0.122061
# 55                  Number.of.Unsuccessful.Grant.1_0    0.077376
# 54                    Number.of.Successful.Grant.1_0    0.042580
# 24                      Number.of.Successful.Grant.1    0.034511
# 285                      Sponsor.Code_no_information    0.025847
# 298               Grant.Category.Code_no_information    0.024798
# 30                                     RFCD.Code.1_0    0.017424
# 40                                      SEO.Code.1_0    0.015053
# 0                                        RFCD.Code.1    0.014424
# 50                                     Person.ID.1_0    0.014405
# 10                                        SEO.Code.1    0.014169
# 52                                      Dept.No..1_0    0.013780
# 27                                               A.1    0.013617
# 12                                        SEO.Code.2    0.013478

# %% [markdown]
# `ВЫВОДЫ:`
#
# Модель `LogisticRegressionCV` - `roc_auc_score` = 0.`85438`
#
# --- Фичи по важности ---
#
# - 53	Faculty.No..1_0	                                - 1.909341
# - 51	Year.of.Birth.1_0	                            - 1.887674
# - 23	Faculty.No..1	                                - 1.520222
# - 314	Contract.Value.Band...see.note.A_no_information	- 1.455511
#
#
# Модель `RandomForestClassifier` - `roc_auc_score` = 0.`91339`
#
# --- Фичи по важности ---
#
# - 314	Contract.Value.Band...see.note.A_no_information	- 0.173428
# - 25	Number.of.Unsuccessful.Grant.1	                - 0.122061
# - 55	Number.of.Unsuccessful.Grant.1_0	            - 0.077376
# - 54	Number.of.Successful.Grant.1_0	                - 0.042580
#
# > При подготовке данных для построения моделей приходится очень плотно работать с датасетом, погружаться в данные, разбираться в логических связях.
# При обучении двух моделей видна существенная разница в результате (согласно метрики roc_auc_score). Интересным, так же является потраченное время на подбор гиперпараметров
# модели RandomForestClassifier при помощи GridSearchCV (у меня было два результата 27 и 47 минут), так же при просмотре первых 4х самых важных фичей у каждой модели можно заметить сходство, только по одной фиче - `314	Contract.Value.Band...see.note.A_no_information`
